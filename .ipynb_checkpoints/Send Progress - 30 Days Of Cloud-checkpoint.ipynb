# %%
import pandas as pd
df = pd.read_csv('progressf.csv')
for ind in df.index:
    print(df['Student Email'][ind])
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-f307dad5cec5> in <module>
#       1 import cv2
#       2 image = cv2.imread('https://tinyjpg.com/images/social/website.jpg')
# ----> 3 rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       4
#       5 boxes = face_recognition.face_locations(rgb, model=args["detection_method"])
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import smtplib, ssl
from IPython.core.display import display, HTML
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

port = 465  # For SSL
smtp_server = "smtp.gmail.com"
sender_email = "dsc@vjti.ac.in"  # Enter your address
password = "dsc@2021P" # Enter your password
for ind in df.index:
    print(df['Student Name'][ind],df['Student Email'][ind])
    name=df['Student Name'][ind]
    mail=df['Student Email'][ind]
    message = MIMEMultipart("alternative")
    message["Subject"] = "30 days of Google Cloud"

    receiver_email = mail  # Enter receiver address
    html = """\
    <html>
 <table border="0" width="600" cellspacing="0" cellpadding="0" align="center" bgcolor="#FFFFFF">
  <tbody>
    <tr>
      <td id="gmail-theBigContainer" align="center" valign="top">
        <table id="gmail-headerModule" border="0" width="600" cellspacing="0" cellpadding="0" align="center">
          <tbody>
            <tr>
              <td id="gmail-header-logos" align="center" valign="top">
                <table style="width: 600px; height: 16px;" border="0" width="600" cellspacing="0" cellpadding="0" align="center">
                  <tbody>
                    <tr style="height: 16px;">
                      <td style="width: 300px; height: 16px;" align="left" valign="top">
                        <br>
                      </td>
                      <td style="width: 300px; height: 16px;" align="right" valign="top">&nbsp;</td>
                    </tr>
                  </tbody>
                </table>
              </td>
            </tr>
          </tbody>
        </table>
      </td>
    </tr>
  </tbody>
</table>
<p>
  <span style="font-family: helvetica, arial, sans-serif;">
    <img style="float: left;" src="https://ci4.googleusercontent.com/proxy/kbXwXhEWfsZvlZvNkbOq4fEC_NCGoo9-7-XTBc9B25WAaEiiGx3bkoyLCIy-M27psiUZJeP8ndul9dAI-Vx6woD1FzUauANrIxcqKH5xmuJbt7WR82GB3qRa5CPdOzBoM6nMufZr0OzXKV4z6WE=s0-d-e1-ft#https://lp.cloudplatformonline.com/rs/808-GJW-314/images/evt_Google_Cloud_logo_new%402x.png" alt="Google Cloud" width="180" height="28">&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; 
    <br>
    <br>
  </span> 
  <br>
  <span style="font-family: helvetica, arial, sans-serif;">
    <img style="display: block; margin-left: auto; margin-right: auto;" src="https://share1.cloudhq-mkt3.net/34bf76737d2f93.jpeg" alt="" width="403" height="184">
  </span>
</p>
<table id="gmail-heroModuleb29c98b4-7be1-44cf-b196-0ff1e11e3bbb" style="height: 17px;" border="0" width="600" cellspacing="0" cellpadding="0" align="center">
  <tbody>
    <tr style="height: 17px;">
      <td style="height: 17px; width: 600px;" align="center" valign="top">
        <span style="font-family: helvetica, arial, sans-serif;">&nbsp;</span>
      </td>
    </tr>
  </tbody>
</table>
<table id="gmail-greetingModulede787cf3-2bd8-4e67-95ab-7819270408fe" border="0" width="600" cellspacing="0" cellpadding="0" align="center">
  <tbody>
    <tr>
      <td align="center" valign="top">
        <table style="height: 16px;" border="0" width="600" cellspacing="0" cellpadding="0" align="center">
          <tbody>
            <tr style="height: 16px;">
              <td style="height: 16px; width: 600px;">
                <span style="font-family: helvetica, arial, sans-serif;">&nbsp;</span>
              </td>
            </tr>
          </tbody>
        </table>
      </td>
    </tr>
  </tbody>
</table>
<span style="font-family: arial, helvetica, sans-serif;">
  <strong>
    <span style="font-size: 12pt; color: #000000; background-color: #ffffff;">Dear Student,</span>
  </strong>
</span>
<p>
  <span style="font-weight: 400;">Congratulations on completing the</span> 30 Days of Google Cloud Program.Thank you for participating and completing your milestone in the program.&nbsp;
</p>
<ul>
  <li>
    <span style="font-size: 10pt;">
      <strong>
        <span style="background-color: #ffff00;">What's next?</span> You will be getting a mail from Google Cloud to confirm your shipping address and other details so that you claim your prize. 
        <span style="background-color: #ffffff; color: #ff0000;">That mail from Google will come next week.</span>&nbsp; After you fill the form they send you, your prizes will be delivered to you. 
        <br>
        <br>
      </strong>
    </span>
  </li>
  <li>
    <span style="font-size: 10pt;">Developer Student Clubs(DSC) is one of the communities of Google and there is a total of 275 DSC's across India. One of which is ours and hence our college got to be a part of this cloud program. 
      <span style="background-color: #ffffff;">If you wish to stay connected to DSC VJTI for more such activities or even be a part of this community, please feel free to download the slack app( 
        <a href="https://join.slack.com/t/dsc-%20vjti/signup" style="background-color: #ffffff;">VJTI chat group - Slack</a>)
      </span>and all details will be sent there.&nbsp;
    </span> 
    <span style="font-size: 10pt;">
      <br>
      <br>
    </span>
  </li>
  <li>Share your experience and learning with the Cloud Program. We will be publishing your words and as a recognition of your participation in this program to the 
    <span style="background-color: #ffff00;">medium handle of DSC VJTI and create a blogging space for coders</span>! Also if you attended the Study Jam Sessions conducted we would appreciate it if you give feedback for that as well.&nbsp; 
    <br>Form for sharing your experience and feedback: 
    <a href="http://bit.ly/cloud-experience">http://bit.ly/cloud-experience</a> 
    <br>
    <br>
  </li>
  <li>As the last point, a reminder to you to be proud of the skill badges that you have earned and keep exploring Google Cloud Platform with the credits you have. You can also share your skill badges on LinkedIn.
    <br>
  </li>
</ul>
<p style="text-align: left;">
  <span style="font-family: helvetica, arial, sans-serif;">
    <span style="font-size: 10pt; background-color: #ffffff; color: #000000; font-family: arial, helvetica, sans-serif;">Thanks and Regards, 
      <br>Team DSC VJTI
    </span> 
    <span style="font-size: 12pt;">
      <br>
    </span>
  </span>
</p>
<div style="text-align: center;">
  <span style="font-family: helvetica, arial, sans-serif;">
    <span style="font-size: 10pt; background-color: #ffffff; color: #000000; font-family: arial, helvetica, sans-serif;">
      <span style="font-size: 12pt; background-color: #ffffff; color: #000000;">
        <span style="font-size: 10pt;">Connect with the new DSC VJTI community on 
          <a href="bit.ly/linkedIn-dscvjti">LinkedIn</a> and 
          <a href="bit.ly/youtube-dscvjti">YouTube</a>
        </span> 
        <br>
      </span>
    </span>
  </span>
</div>
<div style="text-align: center;">
  <span style="font-family: helvetica, arial, sans-serif;">
    <span style="font-size: 12pt;">
      <br>
    </span>
  </span>
</div>

</html>
    """
    part2 = MIMEText(html, "html")
    message.attach(part2)

# send your email
    context = ssl.create_default_context()
    with smtplib.SMTP_SSL(smtp_server, port, context=context) as server:
        server.login(sender_email, password)
        server.sendmail(sender_email, receiver_email, message.as_string())
# Out:
# Neha Vijay Khairnar nvkhairnar_b19@it.vjti.ac.in
# Saurav Kanegaonkar saurav.kanegaonkar@gmail.com
# Pranay Nandkumar Patil pnpatil_19@mc.vjti.ac.in
# Satish Ashok Gangula satishgangula25@gmail.com
# Nishit Nikhil Salot nnsalot_b17@it.vjti.ac.in
# Pandey Surendrakumar Anuruddhaprasad sapandey_b18@ce.vjti.ac.in
# Nikheel Indanoor nrindanoor_b19@ce.vjti.ac.in
# Aditya Tanaji Darndale atdarandale_b19@it.vjti.ac.in
# Rohan Vora rrvora_b18@gmail.com
# Vishal Rajaram Dhanawade vishaldhanawade0707@gmail.com
# Prathamesh Harishchandra Parulekar phparulekar_18@mc.vjti.ac.in
# Azeez Dandawala officialazeezamd@gmail.com
# Sandesh Pramod Kalambe spkalambe_b17@ce.vjti.ac.in
# Hrim Gandhi hdgandhi_b18@ce.vjti.ac.in
# Prathamesh Tagore prathameshtagore@gmail.com
# Priyanka Avhad pravhad_b19@ce.vjti.ac.in
# Prathamesh Rajesh Ekar pratham.ekar@gmail.com
# Naveen Sohan Singh Rawat nsrawat_b17@it.vjti.ac.in
# Priyanshi Vikas Gupta pvgupta_b18@it.vjti.ac.in
# Shreyash Vijaykar svijaykar185@gmail.com
# ...
